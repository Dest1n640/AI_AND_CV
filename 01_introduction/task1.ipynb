# %%
import numpy as np 
import matplotlib.pyplot as plt
from skimage.measure import label
import cv2
from skimage.measure import label, regionprops

# %%
for i in range(0, 10):
  image = cv2.imread(f"task_1/0{i}.png")
  gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
  binary = np.zeros_like(gray)
  binary[gray < 100] = 0
  binary[gray >= 100] = 1
  plt.imshow(binary, cmap='gray')
  plt.show()
  labeled_array, count = label(binary, return_num=True)
  regions = regionprops(labeled_array)
  area = 0
  for region in regions:
    area += region.area
  print(f"image0{i} = {area}")
# Out:
# image00 = 22754.0
# image01 = 12936.0
# image02 = 21449.0
# image03 = 24111.0
# image04 = 21856.0
# image05 = 29539.0
# image06 = 19062.0
# image07 = 22548.0
# image08 = 28652.0
# image09 = 19917.0
